# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
df = pd.read_csv( r"C:\Users\anjal\Downloads\archive (1)\stock_market_data\nasdaq\csv\AAPL.csv")
df.head()
# Out:
#          Date       Low      Open     Volume      High     Close  \
# 0  12-12-1980  0.128348  0.128348  469033600  0.128906  0.128348
# 1  15-12-1980  0.121652  0.122210  175884800  0.122210  0.121652
# 2  16-12-1980  0.112723  0.113281  105728000  0.113281  0.112723
# 3  17-12-1980  0.115513  0.115513   86441600  0.116071  0.115513
# 4  18-12-1980  0.118862  0.118862   73449600  0.119420  0.118862
#
#    Adjusted Close
# 0        0.099874
# 1        0.094663
# 2        0.087715
# 3        0.089886
# 4        0.092492

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
df = df.sort_values("Date")

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")

# %%
features = ["Open", "High", "Low", "Close", "Volume"]
data = df[features]

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# %%
def create_sequences(data, window_size=30):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size, 3])  # Close price index
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, window_size=30)

print(X.shape, y.shape)
# Out:
# (10560, 30, 5) (10560,)

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close']].values)

# %%
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, seq_len=60)

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)

dataset = TensorDataset(X, y)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
class LSTMModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=64, batch_first=True)
        self.fc = nn.Linear(64, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

model = LSTMModel()

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
for epoch in range(10):
    for xb, yb in loader:
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.6f}")
# Out:
# Epoch 1, Loss: 0.000004
# Epoch 2, Loss: 0.000007
# Epoch 3, Loss: 0.000007
# Epoch 4, Loss: 0.000030
# Epoch 5, Loss: 0.000008
# Epoch 6, Loss: 0.000005
# Epoch 7, Loss: 0.000062
# Epoch 8, Loss: 0.000000
# Epoch 9, Loss: 0.000357
# Epoch 10, Loss: 0.000012

# %%
train_size = int(len(X) * 0.8)

# %%
X_train = X[:train_size]
y_train = y[:train_size]

X_test = X[train_size:]
y_test = y[train_size:]

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)

X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)
# Out:
# C:\Users\anjal\AppData\Local\Temp\ipykernel_15148\4167845383.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train = torch.tensor(X_train, dtype=torch.float32)
# C:\Users\anjal\AppData\Local\Temp\ipykernel_15148\4167845383.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train, dtype=torch.float32)
# C:\Users\anjal\AppData\Local\Temp\ipykernel_15148\4167845383.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test = torch.tensor(X_test, dtype=torch.float32)
# ...

# %%
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([8424, 60, 1]) torch.Size([8424, 1])
# torch.Size([2106, 60, 1]) torch.Size([2106, 1])

# %%
model.eval()

with torch.no_grad():
    y_pred = model(X_test)

# %%
y_test_np = y_test.cpu().numpy()
y_pred_np = y_pred.cpu().numpy()

# %%
y_test_inv = scaler.inverse_transform(y_test_np)
y_pred_inv = scaler.inverse_transform(y_pred_np)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test_inv, label="Actual Price")
plt.plot(y_pred_inv, label="Predicted Price")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.title("Actual vs Predicted Stock Price")
plt.legend()
plt.show()

# %%
model.eval()
with torch.no_grad():
    y_pred = model(X_test)

# %%
y_test_np = y_test.cpu().numpy()
y_pred_np = y_pred.cpu().numpy()

# %%
y_test_inv = scaler.inverse_transform(y_test_np.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred_np.reshape(-1, 1))

# %%
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 1.9949618577957153
# RMSE: 2.789517149212518

# %%
class ImprovedLSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size1=128, hidden_size2=64, num_layers=2, dropout=0.2):
        super().__init__()
        # LSTM layers
        self.lstm = nn.LSTM(
            input_size=input_size, 
            hidden_size=hidden_size1, 
            num_layers=num_layers, 
            batch_first=True,
            dropout=dropout
        )
        # Fully connected layer
        self.fc1 = nn.Linear(hidden_size1, hidden_size2)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size2, 1)
    
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc1(out[:, -1, :])
        out = self.relu(out)
        out = self.fc2(out)
        return out

# Create model
model = ImprovedLSTM()

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 5  # Reduced from 20 to 5

for epoch in range(epochs):
    model.train()
    for xb, yb in train_loader:
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
    
    # Validation loss
    model.eval()
    with torch.no_grad():
        val_preds = model(X_test)
        val_loss = criterion(val_preds, y_test)
    
    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {loss.item():.6f}, Val Loss: {val_loss.item():.6f}")
# Out:
# Epoch 1/5 - Train Loss: 0.000071, Val Loss: 0.136796
# Epoch 2/5 - Train Loss: 0.000713, Val Loss: 0.146854
# Epoch 3/5 - Train Loss: 0.000193, Val Loss: 0.140146
# Epoch 4/5 - Train Loss: 0.000402, Val Loss: 0.141332
# Epoch 5/5 - Train Loss: 0.000154, Val Loss: 0.139582

# %%
import torch
import torch.nn as nn

class TimeSeriesTransformer(nn.Module):
    def __init__(self, input_size=1, seq_len=60, d_model=64, nhead=4, num_layers=2, dim_feedforward=128, dropout=0.1):
        super().__init__()
        self.seq_len = seq_len
        self.d_model = d_model
        
        # Linear projection to d_model dimensions
        self.input_proj = nn.Linear(input_size, d_model)
        
        # Transformer Encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # Final regression head
        self.fc = nn.Linear(d_model, 1)
        
    def forward(self, x):
        # x shape: (batch_size, seq_len, input_size)
        x = self.input_proj(x)                  # (batch_size, seq_len, d_model)
        x = self.transformer(x)                 # (batch_size, seq_len, d_model)
        out = self.fc(x[:, -1, :])              # Take last time step for prediction
        return out

# %%
model = TimeSeriesTransformer(
    input_size=1,
    seq_len=60,
    d_model=64,
    nhead=4,
    num_layers=2
)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 5

for epoch in range(epochs):
    model.train()
    for xb, yb in train_loader:
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
    
    # Validation
    model.eval()
    with torch.no_grad():
        val_preds = model(X_test)
        val_loss = criterion(val_preds, y_test)
    
    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {loss.item():.6f}, Val Loss: {val_loss.item():.6f}")
# Out:
# Epoch 1/5 - Train Loss: 0.000539, Val Loss: 0.216360
# Epoch 2/5 - Train Loss: 0.001362, Val Loss: 0.191022
# Epoch 3/5 - Train Loss: 0.000981, Val Loss: 0.175408
# Epoch 4/5 - Train Loss: 0.000140, Val Loss: 0.153720
# Epoch 5/5 - Train Loss: 0.000670, Val Loss: 0.131198

# %%
model.eval()
with torch.no_grad():
    y_pred = model(X_test)

# Convert back to actual prices
y_pred_inv = scaler.inverse_transform(y_pred.cpu().numpy())
y_test_inv = scaler.inverse_transform(y_test.cpu().numpy())

import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.plot(y_test_inv, label="Actual")
plt.plot(y_pred_inv, label="Predicted")
plt.legend()
plt.show()

# %%
# ===============================
# 1️⃣ IMPORT LIBRARIES
# ===============================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# ===============================
# 2️⃣ LOAD DATA
# ===============================
df = pd.read_csv(r"C:\Users\anjal\Downloads\archive (1)\stock_market_data\nasdaq\csv\AAPL.csv")

# Keep relevant features
features = ['Open', 'High', 'Low', 'Close', 'Volume']
df = df[features]

# ===============================
# 3️⃣ SCALE DATA
# ===============================
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

# ===============================
# 4️⃣ CREATE SEQUENCES
# ===============================
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, 3])  # Close price is target (index 3)
    return np.array(X), np.array(y)

seq_len = 60
X, y = create_sequences(scaled_data, seq_len=seq_len)

# ===============================
# 5️⃣ TRAIN/TEST SPLIT
# ===============================
train_size = int(len(X) * 0.8)

X_train = X[:train_size]
y_train = y[:train_size]

X_test = X[train_size:]
y_test = y[train_size:]

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# DataLoaders
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# ===============================
# 6️⃣ DEFINE TRANSFORMER MODEL
# ===============================
class TimeSeriesTransformer(nn.Module):
    def __init__(self, input_size=5, seq_len=60, d_model=64, nhead=4, num_layers=2, dim_feedforward=128, dropout=0.1):
        super().__init__()
        self.seq_len = seq_len
        self.d_model = d_model
        self.input_proj = nn.Linear(input_size, d_model)
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Linear(d_model, 1)
        
    def forward(self, x):
        x = self.input_proj(x)
        x = self.transformer(x)
        out = self.fc(x[:, -1, :])
        return out

model = TimeSeriesTransformer(input_size=X_train.shape[2], seq_len=seq_len)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# ===============================
# 7️⃣ TRAINING LOOP
# ===============================
epochs = 5  # you can increase later

for epoch in range(epochs):
    model.train()
    for xb, yb in train_loader:
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
    
    # Validation loss
    model.eval()
    with torch.no_grad():
        val_preds = model(X_test)
        val_loss = criterion(val_preds, y_test)
    
    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {loss.item():.6f}, Val Loss: {val_loss.item():.6f}")

# ===============================
# 8️⃣ PREDICTION & INVERSE SCALE
# ===============================
model.eval()
with torch.no_grad():
    y_pred = model(X_test)

y_pred_np = y_pred.cpu().numpy()
y_test_np = y_test.cpu().numpy()

# Inverse scaling (only Close column)
close_scaler = MinMaxScaler()
close_scaler.min_, close_scaler.scale_ = scaler.min_[3], scaler.scale_[3]  # Close column index = 3

y_pred_inv = y_pred_np * (1/close_scaler.scale_) - close_scaler.min_/close_scaler.scale_
y_test_inv = y_test_np * (1/close_scaler.scale_) - close_scaler.min_/close_scaler.scale_

# ===============================
# 9️⃣ EVALUATION
# ===============================
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))

print("MAE:", mae)
print("RMSE:", rmse)

# ===============================
# 🔟 PLOTTING
# ===============================
plt.figure(figsize=(12,6))
plt.plot(y_test_inv, label="Actual Close")
plt.plot(y_pred_inv, label="Predicted Close")
plt.title("Transformer Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# Epoch 1/5 - Train Loss: 0.003765, Val Loss: 0.073141
# Epoch 2/5 - Train Loss: 0.000365, Val Loss: 0.087179
# Epoch 3/5 - Train Loss: 0.000505, Val Loss: 0.059404
# Epoch 4/5 - Train Loss: 0.000197, Val Loss: 0.033256
# Epoch 5/5 - Train Loss: 0.000209, Val Loss: 0.021861
# MAE: 16.480520684895954
# RMSE: 26.904037046860434
